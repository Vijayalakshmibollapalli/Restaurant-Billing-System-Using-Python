# %%
import Restaurant_Billing_System as rs
# Out:
# ====== Restaurant Billing ======
# 1. Show Menu
# 2. Place Order
# 3. View Previous Orders
# 4. Exit
# Enter your choice:  1
# ------ MENU CARD ------
# Pizza : ₹250
# Burger : ₹120
# Pasta : ₹180
# French Fries : ₹100
# Cold Coffee : ₹80
# Ice Cream : ₹90
# Biryani : ₹250
# ------------------------
#
# ====== Restaurant Billing ======
# 1. Show Menu
# 2. Place Order
# 3. View Previous Orders
# 4. Exit
# Enter your choice:  2
#
# Enter item name (or 'done' to finish order):  pizza
# Enter quantity for Pizza:  2
# Added 2 Pizza to your order.
# Enter item name (or 'done' to finish order):  done
# ========= BILL =========
# Bill Number : R20251127184949
# Date & Time : 27-11-2025 18:49:49
# ------------------------------
# Item           Qty  Price  Total
# ------------------------------
# Pizza          2    250    500
# ------------------------------
# Subtotal : ₹500
# GST      : ₹25.00
# Discount : ₹50.00
# TOTAL    : ₹475.00
# ...
